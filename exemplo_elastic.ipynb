# %%
import pandas as pd
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan

ES_PAGE_SIZE = 10000

START_DATE = "2022-06-06T10:00:00Z"
END_DATE = "2022-06-13T10:05:00Z"

name = '20220606_20220613.csv'

# %%
def recursive_items(dictionary):
    """Unnest dictionary key-value pairs.

    Args:
        dictionary (dict): Dictionary to be evaluated.

    Yields:
        key, value pair
    """    
    for key, value in dictionary.items():
        if type(value) is dict:
            yield from recursive_items(value)
        else:
            yield (key, value)

def list_from_generator(generator):
    """Returns a list containing the generator keys 

    Args:
        generator (generator): Generator from recursive listing

    Returns:
        list: List containing all the nested keys
    """    
    list = []
    for key, value in recursive_items(generator):
        list.append(key)
    return list


es = Elasticsearch(
    cloud_id='netlex:dXMtZWFzdC0xLmF3cy5mb3VuZC5pbyRjZGM5MjVmZDU1MWY0YTY2YjgxNTYyYThkZGE3YTU5MiQzMWI3ZDM3MGUzY2U0OWU5OGVhOGRkNGUxZDJkNjYzOQ==',
    api_key=("wSeQRIEBi9CLWBWhXrYS", "GKhBFW2eQ66Fjd2ZMbmSGg"),
)

result = scan(
    es,
    index='filebeat-netlex-*',
    query={
        "query": {
            "bool": {
                "filter": [
                    {
                        "range": {
                            "@timestamp": {
                                "format": "strict_date_optional_time",
                                "gte": START_DATE,
                                "lte": END_DATE,
                            }
                        }
                    }
                ]
            }
        }
    },
    _source=[
        "@timestamp",
        "message",
        "netlex.company_subdomain",
        "netlex.user_login"
    ],
    size=ES_PAGE_SIZE
)

count = 0
reqs = []

for r in result:
    if 'user_login' not in list_from_generator(r):
        continue
    elif 'company_subdomain' not in list_from_generator(r):
        continue
    req = {
        '@timestamp': r['_source']['@timestamp'],
        'message': r['_source']['message'],
        'netlex.company_subdomain': r['_source']['netlex']['company_subdomain'],
        'netlex.user_login': r['_source']['netlex']['user_login']
    }
    if count % ES_PAGE_SIZE == 0:
        print(count)
    count = count+1
    reqs.append(req)

df = pd.DataFrame(reqs)
df.columns = ['date', 'message', 'subdomain', 'login']
df['message'] = df.message.str.split(']', expand=True).iloc[:, 2]
# df.to_csv(name, index=False)
df.head()
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000

# %%
df = pd.read_csv(name)

REG_EMAIL = '([a-zA-Z0-9._-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9_-]+)'
REG_ID = '[0-9]+'
REG_MESSAGES = '\{(.*?)\}'
REG_KEY = 'key=(.*?)\;context=(.*?)\;method=(.*?)\;runtime=(.*?)'
REG_SIG_ID = '\w+-\w+-\w+-\w+-\w+'
REG_SPREADSHEET = '.+(\.ods)'


df['message'] = df['message'].str.replace('production.INFO: ', '', regex=False)
df['message'] = df['message'].str.strip()
df['message'] = df['message'].str.replace(REG_EMAIL, 'EMAIL', regex=True)
df['message'] = df['message'].str.replace(REG_ID,'ID', regex=True)
df['message'] = df['message'].str.replace(REG_MESSAGES,'MESSAGE', regex=True)
df['message'] = df['message'].str.replace(REG_KEY, 'KEY', regex=True)
df['message'] = df['message'].str.replace(REG_SIG_ID, 'SIGNATURE_ID', regex=True)
df['message'] = df['message'].str.replace(REG_SPREADSHEET, 'SPREADSHEET', regex=True)

mask_rename_document = df['message'].str.contains('document rename ID')
df.loc[mask_rename_document, 'message'] = df.loc[mask_rename_document, 'message'].str.split('-', expand=True)[0] + 'RENAMED_OLD_NEW'
mask_change_owner_document = df['message'].str.contains('change owner ID')
df.loc[mask_change_owner_document, 'message'] = df.loc[mask_change_owner_document, 'message'].str.split('-', expand=True)[0] + 'OWNER_OLD_NEW'
mask_change_owners_document = df['message'].str.contains('Change owner multiple documents')
df.loc[mask_change_owners_document, 'message'] = df.loc[mask_change_owners_document, 'message'].str.split(':', expand=True)[0] + ' NEW_OWNERS'
mask_pdf_error = df['message'].str.contains('Error in PDFConverter in document_id')
df.loc[mask_pdf_error, 'message'] = df.loc[mask_pdf_error, 'message'].str.split(':', expand=True)[0] + ' ERROR_MESSAGE'
mask_signature_request = df['message'].str.contains('signature request sent')
df.loc[mask_signature_request, 'message'] = 'signature request sent ID'
mask_conversion_error = df['message'].str.contains('PDF converter - conversion error')
df.loc[mask_conversion_error, 'message'] = 'PDF converter - conversion error: ERROR_MESSAGE'
mask_ldap_login_attempt = df['message'].str.contains('LDAP login attempt - login')
df.loc[mask_ldap_login_attempt, 'message'] = 'LDAP login attempt - login: LDAP_USER_LOGIN'
mask_login_attempt = df['message'].str.contains('Login attempt with Credentials - login')
df.loc[mask_login_attempt, 'message'] = 'Login attempt with credentials - login: LDAP_USER_LOGIN'
mask_token_error = df['message'].str.contains('signature adobe sign refresh token error Client error')
df.loc[mask_token_error, 'message'] = 'signature adobe sign refresh token error Client error: CLIENT_TOKEN_ERROR_MESSAGE'

df = df.loc[~df['message'].str.contains('production.ERROR')]

# %%
sorted(df['message'].unique())
# Out:
# ['Change owner multiple documents, ids NEW_OWNERS',
#  'Disassociated workflowId "ID" from templateId "ID"',
#  'Error in PDFConverter in document_id ERROR_MESSAGE',
#  'Invalid credentials',
#  'KEYID.ID',
#  'LDAP Search failed: ldap_search(): Search: Operations error',
#  'LDAP bind failed',
#  'LDAP bind failed: ldap_bind(): Unable to bind to server: Invalid credentials',
#  'LDAP bind successful',
#  'LDAP binding for auth',
#  'LDAP binding for search',
#  'LDAP login attempt - login: LDAP_USER_LOGIN',
#  'LDAP user not found',
#  'LDAP user not found in directory',
#  'LDAP using fallback bind',
#  'LDAP using fallback bind with credentials',
#  'Login attempt with SAML - requested',
#  'Login attempt with credentials - login: LDAP_USER_LOGIN',
#  'NULL returned',
#  'PDF converter - already exists',
#  'PDF converter - conversion error: ERROR_MESSAGE',
#  'PDF converter - converted with cloudconvert',
#  'PDF converter - converted with soffice',
#  'PDF converter - pdfunite error: [',
#  'Questionnaire Configs not mapped between oldTemplateVersionId: ID, newTemplateVersionId: ID',
#  'SAML config created',
#  'SAML config deleted',
#  'SPREADSHEET',
#  'User is blocked',
#  'User not allowed',
#  'User not found',
#  'Using IdP init',
#  'abstract.get ID',
#  'alert.create ID',
#  'alert.update ID',
#  'answers.download ID',
#  'attachment.create ID',
#  'attachment.destroy ID',
#  'attachment.download ID',
#  'auth person role create ID',
#  'auth person role remove ID',
#  'auth person role upsert ID',
#  'auth role create ID',
#  'auth role delete ID',
#  'auth role permission create ID admin',
#  'auth role permission create ID calendar create',
#  'auth role permission create ID calendar delete',
#  'auth role permission create ID calendar read',
#  'auth role permission create ID calendar update',
#  'auth role permission create ID connect create',
#  'auth role permission create ID connect delete',
#  'auth role permission create ID connect execute',
#  'auth role permission create ID connect read',
#  'auth role permission create ID connect update',
#  'auth role permission create ID connect variable_manage',
#  'auth role permission create ID contact create',
#  'auth role permission create ID contact delete',
#  'auth role permission create ID contact read',
#  'auth role permission create ID contact update',
#  'auth role permission create ID document attachment_create ID',
#  'auth role permission create ID document attachment_delete ID',
#  'auth role permission create ID document create ID',
#  'auth role permission create ID document create_external ID',
#  'auth role permission create ID document create_external_version ID',
#  'auth role permission create ID document delete ID',
#  'auth role permission create ID document download_docx ID',
#  'auth role permission create ID document download_pdf ID',
#  'auth role permission create ID document metadata_create ID',
#  'auth role permission create ID document metadata_delete ID',
#  'auth role permission create ID document metadata_update ID',
#  'auth role permission create ID document note_create ID',
#  'auth role permission create ID document read ID',
#  'auth role permission create ID document rename IDRENAMED_OLD_NEW',
#  'auth role permission create ID document restore_version ID',
#  'auth role permission create ID document revision ID',
#  'auth role permission create ID document share ID',
#  'auth role permission create ID document signature_read ID',
#  'auth role permission create ID document signature_send ID ID',
#  'auth role permission create ID document task_create ID',
#  'auth role permission create ID document task_read ID',
#  'auth role permission create ID document update_editor ID',
#  'auth role permission create ID document update_questionnaire ID',
#  'auth role permission create ID document_prefix create',
#  'auth role permission create ID document_prefix delete',
#  'auth role permission create ID document_prefix read',
#  'auth role permission create ID document_prefix update',
#  'auth role permission create ID document_type create',
#  'auth role permission create ID document_type delete',
#  'auth role permission create ID document_type update',
#  'auth role permission create ID external_links_cards read',
#  'auth role permission create ID faq create',
#  'auth role permission create ID faq delete',
#  'auth role permission create ID faq update',
#  'auth role permission create ID intelligence create ID',
#  'auth role permission create ID intelligence delete ID',
#  'auth role permission create ID intelligence read ID',
#  'auth role permission create ID intelligence update ID',
#  'auth role permission create ID lexin download',
#  'auth role permission create ID management create_update_delete',
#  'auth role permission create ID management read',
#  'auth role permission create ID root_folder create',
#  'auth role permission create ID root_folder delete',
#  'auth role permission create ID root_folder update',
#  'auth role permission create ID team create',
#  'auth role permission create ID team delete',
#  'auth role permission create ID team transfer_responsibility',
#  'auth role permission create ID team update',
#  'auth role permission create ID template create ID',
#  'auth role permission create ID template delete ID',
#  'auth role permission create ID template read ID',
#  'auth role permission create ID template subtemplate_create',
#  'auth role permission create ID template subtemplate_delete',
#  'auth role permission create ID template subtemplate_read',
#  'auth role permission create ID template subtemplate_update',
#  'auth role permission create ID template update ID',
#  'auth role permission create ID user create',
#  'auth role permission create ID user delete',
#  'auth role permission create ID user read',
#  'auth role permission create ID user transfer_responsibility',
#  'auth role permission create ID user update',
#  'auth role permission create ID user_role create',
#  'auth role permission create ID user_role delete',
#  'auth role permission create ID user_role read',
#  'auth role permission create ID user_role update',
#  'auth role permission create ID workflow alter_sla ID',
#  'auth role permission create ID workflow cancel ID',
#  'auth role permission create ID workflow clarification ID',
#  'auth role permission create ID workflow delete ID',
#  'auth role permission create ID workflow obtain_responsibility ID',
#  'auth role permission create ID workflow reactivate ID',
#  'auth role permission create ID workflow read ID',
#  'auth role permission create ID workflow upsert ID',
#  'auth role permission remove ID admin',
#  'auth role permission remove ID calendar create',
#  'auth role permission remove ID calendar delete',
#  'auth role permission remove ID calendar read',
#  'auth role permission remove ID calendar update',
#  'auth role permission remove ID connect create',
#  'auth role permission remove ID connect delete',
#  'auth role permission remove ID connect execute',
#  'auth role permission remove ID connect read',
#  'auth role permission remove ID connect update',
#  'auth role permission remove ID connect variable_manage',
#  'auth role permission remove ID contact create',
#  'auth role permission remove ID contact delete',
#  'auth role permission remove ID contact read',
#  'auth role permission remove ID contact update',
#  'auth role permission remove ID document attachment_create ID',
#  'auth role permission remove ID document attachment_delete ID',
#  'auth role permission remove ID document create ID',
#  'auth role permission remove ID document create_external ID',
#  'auth role permission remove ID document create_external_version ID',
#  'auth role permission remove ID document delete ID',
#  'auth role permission remove ID document download_docx ID',
#  'auth role permission remove ID document download_pdf ID',
#  'auth role permission remove ID document metadata_create ID',
#  'auth role permission remove ID document metadata_delete ID',
#  'auth role permission remove ID document metadata_update ID',
#  'auth role permission remove ID document note_create ID',
#  'auth role permission remove ID document read ID',
#  'auth role permission remove ID document rename IDRENAMED_OLD_NEW',
#  'auth role permission remove ID document restore_version ID',
#  'auth role permission remove ID document revision ID',
#  'auth role permission remove ID document share ID',
#  'auth role permission remove ID document signature_read ID',
#  'auth role permission remove ID document signature_send ID ID',
#  'auth role permission remove ID document task_create ID',
#  'auth role permission remove ID document task_read ID',
#  'auth role permission remove ID document update_editor ID',
#  'auth role permission remove ID document update_questionnaire ID',
#  'auth role permission remove ID document_prefix create',
#  'auth role permission remove ID document_prefix delete',
#  'auth role permission remove ID document_prefix read',
#  'auth role permission remove ID document_prefix update',
#  'auth role permission remove ID document_type create',
#  'auth role permission remove ID document_type delete',
#  'auth role permission remove ID document_type update',
#  'auth role permission remove ID external_links_cards read',
#  'auth role permission remove ID faq delete',
#  'auth role permission remove ID faq update',
#  'auth role permission remove ID management create_update_delete',
#  'auth role permission remove ID management read',
#  'auth role permission remove ID root_folder create',
#  'auth role permission remove ID root_folder delete',
#  'auth role permission remove ID root_folder update',
#  'auth role permission remove ID team create',
#  'auth role permission remove ID team delete',
#  'auth role permission remove ID team transfer_responsibility',
#  'auth role permission remove ID team update',
#  'auth role permission remove ID template create ID',
#  'auth role permission remove ID template delete ID',
#  'auth role permission remove ID template read ID',
#  'auth role permission remove ID template subtemplate_create',
#  'auth role permission remove ID template subtemplate_delete',
#  'auth role permission remove ID template subtemplate_read',
#  'auth role permission remove ID template subtemplate_update',
#  'auth role permission remove ID template update ID',
#  'auth role permission remove ID user create',
#  'auth role permission remove ID user delete',
#  'auth role permission remove ID user read',
#  'auth role permission remove ID user transfer_responsibility',
#  'auth role permission remove ID user update',
#  'auth role permission remove ID user_role create',
#  'auth role permission remove ID user_role delete',
#  'auth role permission remove ID user_role read',
#  'auth role permission remove ID user_role update',
#  'auth role permission remove ID workflow alter_sla ID',
#  'auth role permission remove ID workflow cancel ID',
#  'auth role permission remove ID workflow clarification ID',
#  'auth role permission remove ID workflow create ID',
#  'auth role permission remove ID workflow delete ID',
#  'auth role permission remove ID workflow obtain_responsibility ID',
#  'auth role permission remove ID workflow reactivate ID',
#  'auth role permission remove ID workflow read ID',
#  'auth role permission remove ID workflow update ID',
#  'auth role permission remove ID workflow upsert ID',
#  'auth role permission upsert ID',
#  'auth role update ID',
#  'clicksign signer create',
#  'clicksign signer created SIGNATURE_ID',
#  'connect script api token create ID',
#  'connect script api token created ID ID',
#  'connect script api token get ID',
#  'connect script delete ID',
#  'connect script deleted [true,"SCRIPT_DELETED"',
#  'connect script execute ID',
#  'connect script executed ID ID',
#  'connect script message trigger create ID',
#  'connect script message trigger created ID ID',
#  'connect script message trigger delete ID',
#  'connect script message trigger deleted [true,"TRIGGER_DELETED"',
#  'connect script upsert',
#  'connect script upsert ID',
#  'connect script upserted ID',
#  'connect variable get',
#  'contact create ID',
#  'contact delete ID',
#  'contact read ID',
#  'contact update ID',
#  'destroy ID',
#  'document change owner ID OWNER_OLD_NEW',
#  'document create ID',
#  'document delete ID',
#  'document download docx ID',
#  'document download pdf ID',
#  'document download pdf ID  \nID/ID/ID ID:ID:ID [error',
#  'document rename ID RENAMED_OLD_NEW',
#  'document update ID',
#  'document version download abstract ID',
#  'document view ID',
#  'document view ID  \nID/ID/ID ID:ID:ID [error',
#  'document.comment person.in.room create [ID',
#  'document.comment person.in.room create [ID,ID',
#  'document.comment person.in.room create [ID,ID,ID',
#  'document.comment person.in.room create [ID,ID,ID,ID',
#  'document.comment person.in.room delete ID',
#  'document.comment person.in.room update ID',
#  'document.comment room create ID',
#  'document.comment room delete ID',
#  'document.comment room update ID',
#  'docx.download ID',
#  'external.create ID',
#  'external_version.create ID',
#  'info.edit_name ID',
#  'intelligence panel create ID',
#  'intelligence panel delete ID',
#  'intelligence panel read ID',
#  'intelligence panel update ID',
#  'intelligence report ID ID',
#  'intelligence spreadsheet ID',
#  'intelligence spreadsheet generated [netlex',
#  'intelligence widget create ID',
#  'intelligence widget delete ID',
#  'intelligence widget update ID',
#  'internal.create ID',
#  'internal_version.create ID',
#  'login succeeded',
#  'login update user EMAIL',
#  'login updated user EMAIL',
#  'logout',
#  'message sent MESSAGE,"message_reference":"ID"}',
#  'message sent MESSAGE}',
#  'metadata.create ID',
#  'note.create ID',
#  'password recovery EMAIL',
#  'password recovery succeeded',
#  'password recovery user not allowed',
#  'password recovery user not found',
#  'pdf.download ID',
#  'prorrogation.create ID',
#  'questionnaire.edit ID',
#  'request validation failed',
#  'revision add.revisors ID',
#  'revision create ID',
#  'revision document version create ID',
#  'revision finish ID',
#  'revision start ID',
#  'revision.add_revisor ID',
#  'revision.answer ID',
#  'revision.canceled ID',
#  'revision.finished ID',
#  'revision.started ID',
#  'revisor delete ID',
#  'safe link token create ID',
#  'safe link token delete ID',
#  'share ID',
#  'signature adobe sign agreement created',
#  'signature adobe sign create request',
#  'signature adobe sign get sign view',
#  'signature adobe sign refresh token error Client error: CLIENT_TOKEN_ERROR_MESSAGE',
#  'signature adobe sign status view check',
#  'signature certisign send request',
#  'signature certisign void ID',
#  'signature clicksign cancel request',
#  'signature clicksign create request',
#  'signature clicksign document uploaded document key: SIGNATURE_ID',
#  'signature clicksign signature request notification was sent.',
#  'signature clicksign signatures requested',
#  'signature dIDsign cancel request',
#  'signature dIDsign create request',
#  'signature ds create embedded',
#  'signature ds draft envelope created SIGNATURE_ID',
#  'signature ds envelope updated',
#  'signature ds error MESSAGE',
#  'signature ds send request',
#  'signature ds void envelope SIGNATURE_ID',
#  'signature provider remove ID',
#  'signature request cancel ID ID',
#  'signature request cancel failed at provider ID ID',
#  'signature request canceled ID ID',
#  'signature request canceled ID ID ID',
#  'signature request canceled ID ID SIGNATURE_ID',
#  'signature request create ID ID',
#  'signature request send ID ID',
#  'signature request sent ID',
#  'signature.canceled ID',
#  'signature.created ID',
#  'signature.sent ID',
#  'sla extension create ID',
#  'task.create ID',
#  'user create ID EMAIL',
#  'user delete ID',
#  'user save EMAIL',
#  'user save EMAIL ID',
#  'user update ID',
#  'version.restore ID',
#  'visual identity create ID',
#  'visual identity update ID',
#  'visual identity upload background image ID',
#  'visual identity upload logo image ID',
#  'webfill  ID ID ID',
#  'webfill  ID ID http://newextranet.dannemann.com.br/WorkflowHost/ExtranetMarcasService.svc?wsdl',
#  'webfill API Json ID ID SIGNATURE_ID.compute-ID.amazonaws.com/fragataws.php',
#  'webfill API Json ID ID http://ID.ID.ID.ID/getGeneralManagers.php',
#  'webfill CONNECT ID ID ID',
#  'webfill SOAP ID ID http://newextranet.dannemann.com.br/WorkflowHost/ExtranetMarcasService.svc?wsdl',
#  'workflow canceled in current step workflowId=ID stepId=ID',
#  'workflow connect step rule execution ID workflow_id ID script_id ID',
#  'workflow create ID',
#  'workflow finish ID',
#  'workflow reactivated in last active step workflowId=ID stepId=ID',
#  'workflow update ID',
#  'workflow updated from current step workflowId=ID stepId=ID type=elaboration',
#  'workflow updated from current step workflowId=ID stepId=ID type=internal_approval',
#  'workflow updated from current step workflowId=ID stepId=ID type=signature']
